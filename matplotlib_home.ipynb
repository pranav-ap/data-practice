# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# for interactive
#%matplotlib notebook
# for static
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# # Basic

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure() # create a plot figure
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = np.linspace(0, 10, 100)
#       3 fig = plt.figure() # create a plot figure
#       4 plt.plot(x, np.sin(x), '-')
#
# NameError: name 'np' is not defined

# %%
fig.savefig('assets/my_figure.png')

# %% [markdown]
# ## Two Interfaces

# %% [markdown]
# ### Matlab-style

# %%
plt.figure() 

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# ### OOPS-style

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# # Line Plots

# %%
fig = plt.figure() # contains all axes, graphics and text and labels
ax = plt.axes() # the grid below and eventuallly plot elements and labels

# %%
fig = plt.figure() 
ax = plt.axes() 

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
